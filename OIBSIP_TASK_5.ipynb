# %% [markdown]
# <a href="https://colab.research.google.com/github/SadiiMalik/oibsibtask1/blob/main/OIBSIP_TASK_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SADIA RIAZ**
# # **OIBSIP TASK 5**

# %% [markdown]
# # ***OPEN CSV FILE***

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f92266b-d2bd-4c79-8016-d82675693d66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f92266b-d2bd-4c79-8016-d82675693d66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # ***IMPORT LIBRARIES AND READ CSV FILE***

# %%
import io
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time as tm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.impute import SimpleImputer

from mlxtend.preprocessing import minmax_scaling
from scipy import stats

# %%
df = pd.read_csv(io.StringIO(uploaded['Advertising.csv'].decode('utf-8')))

# %% [markdown]
# # ***ANALYZING DATASET***

# %%
df.loc[65:71]
# Out:
#     ID     TV  Radio  Newspaper  Sales
# 65  66   69.0    9.3        0.9    9.3
# 66  67   31.5   24.6        2.2    9.5
# 67  68  139.3   14.5       10.2   13.4
# 68  69  237.4   27.5       11.0   18.9
# 69  70  216.8   43.9       27.2   22.3
# 70  71  199.1   30.6       38.7   18.3
# 71  72  109.8   14.3       31.7   12.4

# %%
tm.time()
# Out:
# 1685870491.8128812

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         200 non-null    int64
#  1   TV         200 non-null    float64
#  2   Radio      200 non-null    float64
#  3   Newspaper  200 non-null    float64
#  4   Sales      200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#                ID          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.mean()
# Out:
# ID           100.5000
# TV           147.0425
# Radio         23.2640
# Newspaper     30.5540
# Sales         14.0225
# dtype: float64

# %%
df.count()
# Out:
# ID           200
# TV           200
# Radio        200
# Newspaper    200
# Sales        200
# dtype: int64

# %%
df.max()
# Out:
# ID           200.0
# TV           296.4
# Radio         49.6
# Newspaper    114.0
# Sales         27.0
# dtype: float64

# %%
df.min()
# Out:
# ID           1.0
# TV           0.7
# Radio        0.0
# Newspaper    0.3
# Sales        1.6
# dtype: float64

# %%
df.sort_values(by=['Sales','TV','Radio','Newspaper'],ascending=True)
# Out:
#       ID     TV  Radio  Newspaper  Sales
# 130  131    0.7   39.6        8.7    1.6
# 155  156    4.1   11.6        5.7    3.2
# 8      9    8.6    2.1        1.0    4.8
# 78    79    5.4   29.9        9.4    5.3
# 108  109   13.1    0.4       25.6    5.3
# ..   ...    ...    ...        ...    ...
# 36    37  266.9   43.8        5.0   25.4
# 98    99  289.7   42.3       51.2   25.4
# 198  199  283.6   42.0       66.2   25.5
# 183  184  287.6   43.0       71.8   26.2
# 175  176  276.9   48.9       41.8   27.0
#
# [200 rows x 5 columns]

# %%
plt.figure(figsize = (8,7))
sns.displot(df['TV'] , color = 'black')
sns.displot(df['Newspaper'], color = 'purple')
sns.displot(df['Radio'], color = 'pink')
plt.show()

# %% [markdown]
# # ***PRE-PROCESSING DATASET***

# %%
miss=df.isnull().sum()
miss[0:7]
# Out:
# ID           0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# # **DROP UNNECESSARY COLUMN**

# %%
df=df.drop(columns=['ID'])

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # ***SCALING OF DATASET***

# %%
df_scaling7 = df.TV
scaled_data7 = minmax_scaling(df_scaling7, columns = [0])

fig, ax = plt.subplots(1,2)
sns.distplot(df.TV, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(scaled_data7, ax=ax[1])
ax[1].set_title("Scaled Data")
# Out:
# Text(0.5, 1.0, 'Scaled Data')

# %%
df_scaling7 = df.Radio
scaled_data7 = minmax_scaling(df_scaling7, columns = [0])

fig, ax = plt.subplots(1,2)
sns.distplot(df.Radio, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(scaled_data7, ax=ax[1])
ax[1].set_title("Scaled Data")
# Out:
# Text(0.5, 1.0, 'Scaled Data')

# %%
df_scaling7 = df.Newspaper
scaled_data7 = minmax_scaling(df_scaling7, columns = [0])

fig, ax = plt.subplots(1,2)
sns.distplot(df.Newspaper, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(scaled_data7, ax=ax[1])
ax[1].set_title("Scaled Data")
# Out:
# Text(0.5, 1.0, 'Scaled Data')

# %% [markdown]
# # ***NORMALIZATON OF DATASET***

# %%
index_of_TV = df.TV > 0
zero_to_one_TV = df.TV.loc[index_of_TV]

normalize_TV = stats.boxcox(zero_to_one_TV)[0]

fig, ax=plt.subplots(1,2)
sns.distplot(zero_to_one_TV, ax=ax[0])
ax[0].set_title("Original Data on TV")
sns.distplot(normalize_TV, ax=ax[1])
ax[1].set_title("Normalized Data on TV")
# Out:
# Text(0.5, 1.0, 'Normalized Data on TV')

# %%
index_of_Radio = df.Radio > 0
zero_to_one_Radio= df.Radio.loc[index_of_Radio]

normalize_Radio = stats.boxcox(zero_to_one_Radio)[0]

fig, ax=plt.subplots(1,2)
sns.distplot(zero_to_one_Radio, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(normalize_Radio, ax=ax[1])
ax[1].set_title("Normalized Data")
# Out:
# Text(0.5, 1.0, 'Normalized Data')

# %%
index_of_Newspaper = df.Newspaper > 0
zero_to_one_Newspaper= df.Newspaper.loc[index_of_Newspaper]

normalize_Newspaper = stats.boxcox(zero_to_one_Newspaper)[0]

fig, ax=plt.subplots(1,2)
sns.distplot(zero_to_one_Newspaper, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(normalize_Newspaper, ax=ax[1])
ax[1].set_title("Normalized Data")
# Out:
# Text(0.5, 1.0, 'Normalized Data')

# %% [markdown]
# # **CORRELATION AND HEATMAP**

# %%
column_1 = df["Sales"]
column_2 = df["TV"]
column_3 = df["Radio"]
column_4 = df["Newspaper"]
correlation1 = column_1. corr(column_2)
correlation2 = column_1. corr(column_3)
correlation3 = column_1. corr(column_4)
print("CORRELATION_1 is ",correlation1)
print("CORRELATION_2 is ",correlation2)
print("CORRELATION_3 is ",correlation3)
# Out:
# CORRELATION_1 is  0.7822244248616061
# CORRELATION_2 is  0.5762225745710551
# CORRELATION_3 is  0.22829902637616528

# %%
def plotCorrelationMatrix(df, graphWidth):
    filename = df
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

plotCorrelationMatrix(df, 8)

# %% [markdown]
# # ***ANALYZING DATASET AFTER CLEANING AND NORMALIZATION***

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.count()
# Out:
# TV           200
# Radio        200
# Newspaper    200
# Sales        200
# dtype: int64

# %%
df.min()
# Out:
# TV           0.7
# Radio        0.0
# Newspaper    0.3
# Sales        1.6
# dtype: float64

# %%
df.max()
# Out:
# TV           296.4
# Radio         49.6
# Newspaper    114.0
# Sales         27.0
# dtype: float64

# %%
df.mean()
# Out:
# TV           147.0425
# Radio         23.2640
# Newspaper     30.5540
# Sales         14.0225
# dtype: float64

# %%
np.random.seed(0)

# %% [markdown]
# # **TESTING AND TRAINING DATASET**

# %%
df['Sales'].value_counts()
# Out:
# 9.7     5
# 11.7    4
# 12.9    4
# 15.9    4
# 20.7    3
#        ..
# 17.0    1
# 18.3    1
# 22.3    1
# 14.0    1
# 25.5    1
# Name: Sales, Length: 121, dtype: int64

# %%
X = df[['TV','Radio','Newspaper']].values
Y = df[['Sales']].values

# %%
X_train, X_test, Y_train,y_test = train_test_split(X,Y,test_size = 0.20, random_state = 0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train,Y_test = train_test_split(X,Y,test_size = 0.20, random_state = 0)

# %% [markdown]
# # **LINEAR REGRESSION**

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X_train,Y_train)
LinearRegression()
Y_predictions=model.predict(X_test)
Y_predictions
# Out:
# array([[10.05739563],
#        [ 7.4522807 ],
#        [ 7.0197076 ],
#        [24.08029725],
#        [12.01786259],
#        [ 6.53793858],
#        [12.78286918],
#        [15.10974587],
#        [10.76974013],
#        [16.34357951],
#        [22.88297477],
#        [ 9.12924467],
#        [10.46455672],
#        [15.48743552],
#        [11.58555633],
#        [12.17296914],
#        [18.76551502],
#        [10.78318566],
#        [15.90515992],
#        [17.30651279],
#        [24.06692057],
#        [ 9.59834224],
#        [15.13512211],
#        [12.38591525],
#        [ 5.71360885],
#        [15.24749314],
#        [12.29402334],
#        [20.9421167 ],
#        [13.40991558],
#        [ 9.04348832],
#        [12.89239415],
#        [21.40272028],
#        [18.13802209],
#        [21.17320803],
#        [ 6.56974433],
#        [ 6.14114206],
#        [ 7.89018394],
#        [13.01541434],
#        [14.68953791],
#        [ 6.18835143]])

# %%
from sklearn import metrics

print('MAE:',metrics.mean_absolute_error(Y_predictions,Y_test))
print('RMSE:',np.sqrt(metrics.mean_squared_error(Y_predictions,Y_test)))
print('R-Squared',metrics.r2_score(Y_predictions,Y_test))
# Out:
# MAE: 1.3617813502090277
# RMSE: 2.0981225634956804
# R-Squared 0.8330284237692486
