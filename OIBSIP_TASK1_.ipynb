# %% [markdown]
# <a href="https://colab.research.google.com/github/SadiiMalik/oibsibtask1/blob/main/OIBSIP_TASK1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SADIA RIAZ**

# %% [markdown]
# # **OPEN CSV FILE**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-655961bb-1bd2-4a6b-b8d9-08849fc35140" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-655961bb-1bd2-4a6b-b8d9-08849fc35140">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **IMPORT LIBRARIES AND READ CSV FILE**

# %%
import warnings
warnings.filterwarnings('ignore')
import io
import pandas as pd
import time as tm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv(io.StringIO(uploaded['Iris.csv'].decode('utf-8')))

# %% [markdown]
# # **ANALYZINF DATASET**

# %%
tm.time()
# Out:
# 1685619681.641717

# %%
df.shape
# Out:
# (150, 6)

# %%
df.loc[59:63]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 59  60            5.2           2.7            3.9           1.4
# 60  61            5.0           2.0            3.5           1.0
# 61  62            5.9           3.0            4.2           1.5
# 62  63            6.0           2.2            4.0           1.0
# 63  64            6.1           2.9            4.7           1.4
#
#             Species
# 59  Iris-versicolor
# 60  Iris-versicolor
# 61  Iris-versicolor
# 62  Iris-versicolor
# 63  Iris-versicolor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.mean()
# Out:
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
df.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
df.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
df.sort_values(by=['SepalLengthCm','SepalWidthCm'],ascending=True)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 8      9            4.4           2.9            1.4           0.2
# 38    39            4.4           3.0            1.3           0.2
# 42    43            4.4           3.2            1.3           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 118  119            7.7           2.6            6.9           2.3
# 122  123            7.7           2.8            6.7           2.0
# 135  136            7.7           3.0            6.1           2.3
# 117  118            7.7           3.8            6.7           2.2
# 131  132            7.9           3.8            6.4           2.0
#
#             Species
# 13      Iris-setosa
# 8       Iris-setosa
# 38      Iris-setosa
# 42      Iris-setosa
# 41      Iris-setosa
# ..              ...
# ...

# %%
df.sort_values(by=['PetalLengthCm','PetalWidthCm'],ascending=True)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 22    23            4.6           3.6            1.0           0.2
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 35    36            5.0           3.2            1.2           0.2
# 2      3            4.7           3.2            1.3           0.2
# ..   ...            ...           ...            ...           ...
# 131  132            7.9           3.8            6.4           2.0
# 105  106            7.6           3.0            6.6           2.1
# 122  123            7.7           2.8            6.7           2.0
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
#
#             Species
# 22      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 35      Iris-setosa
# 2       Iris-setosa
# ..              ...
# ...

# %%
plt.figure(figsize = (8,7))
sns.displot(df['SepalLengthCm'],color = 'red')
sns.displot(df['SepalWidthCm'],color = 'purple')
sns.displot(df['PetalLengthCm'],color = 'orange')
sns.displot(df['PetalWidthCm'])
plt.show()

# %% [markdown]
# # **PRE PROCESSING DATA AND DROPPING EXTRA COLUMN**

# %%
miss=df.isnull().sum()
miss[0:6]
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df=df.drop(columns=['Id'])

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df["Species"].replace({"Iris-setosa": 2, "Iris-versicolor": 3, "Iris-virginica": 4}, inplace = True)

# %% [markdown]
# # **CORRELATION**

# %%
column_1 = df["Species"]
column_2 = df["SepalLengthCm"]
column_3 = df["SepalWidthCm"]
column_4 = df["PetalLengthCm"]
column_5 = df["PetalWidthCm"]
correlation1 = column_1. corr(column_2)
correlation2 = column_1. corr(column_3)
correlation3 = column_1. corr(column_4)
correlation4 = column_1. corr(column_5)
print("CORRELATION_1 is ",correlation1)
print("CORRELATION_2 is ",correlation2)
print("CORRELATION_3 is ",correlation3)
print("CORRELATION_4 is ",correlation4)
# Out:
# CORRELATION_1 is  0.7825612318100819
# CORRELATION_2 is  -0.4194462002600274
# CORRELATION_3 is  0.9490425448523334
# CORRELATION_4 is  0.9564638238016164

# %%
def plotCorrelationMatrix(df, graphWidth):
    filename = df
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

plotCorrelationMatrix(df, 8)

# %% [markdown]
# # **ANALYZING AFTER CLEANING**

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm     Species
# count     150.000000    150.000000     150.000000    150.000000  150.000000
# mean        5.843333      3.054000       3.758667      1.198667    3.000000
# std         0.828066      0.433594       1.764420      0.763161    0.819232
# min         4.300000      2.000000       1.000000      0.100000    2.000000
# 25%         5.100000      2.800000       1.600000      0.300000    2.000000
# 50%         5.800000      3.000000       4.350000      1.300000    3.000000
# 75%         6.400000      3.300000       5.100000      1.800000    4.000000
# max         7.900000      4.400000       6.900000      2.500000    4.000000

# %%
df.max()
# Out:
# SepalLengthCm    7.9
# SepalWidthCm     4.4
# PetalLengthCm    6.9
# PetalWidthCm     2.5
# Species          4.0
# dtype: float64

# %%
df.min()
# Out:
# SepalLengthCm    4.3
# SepalWidthCm     2.0
# PetalLengthCm    1.0
# PetalWidthCm     0.1
# Species          2.0
# dtype: float64

# %%
fig1 = sns.lineplot(x="Species", y="SepalLengthCm", data=df , color = "yellow")
fig2 = sns.lineplot(x="Species", y="SepalWidthCm", data=df, color = "green")
fig3 = sns.lineplot(x="Species", y="PetalLengthCm", data=df, color = "purple")
fig4 = sns.lineplot(x="Species", y="PetalWidthCm", data=df, color = "red")

plt.title("Iris Classification")
plt.show()

# %%
df.sample(5)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 81            5.5           2.4            3.7           1.0        3
# 19            5.1           3.8            1.5           0.3        2
# 0             5.1           3.5            1.4           0.2        2
# 58            6.6           2.9            4.6           1.3        3
# 52            6.9           3.1            4.9           1.5        3

# %%
sns.pairplot(df, hue='Species', size = 3).add_legend()

# %% [markdown]
# # **TESTING AND TRAINING DATASET**

# %%
df['Species'].value_counts()
# Out:
# 2    50
# 3    50
# 4    50
# Name: Species, dtype: int64

# %%
df["Species"].replace({"Iris-setosa": 2, "Iris-versicolor": 3, "Iris-virginica": 4}, inplace = True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        2
# 1              4.9           3.0            1.4           0.2        2
# 2              4.7           3.2            1.3           0.2        2
# 3              4.6           3.1            1.5           0.2        2
# 4              5.0           3.6            1.4           0.2        2
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        4
# 146            6.3           2.5            5.0           1.9        4
# 147            6.5           3.0            5.2           2.0        4
# 148            6.2           3.4            5.4           2.3        4
# 149            5.9           3.0            5.1           1.8        4
#
# [150 rows x 5 columns]

# %%
def split_train_test(data , test_ratio):
  np.random.seed(42)
  shuffled = np.random.permutation(len(data)) #shuffles the random change in arrangement
  print(shuffled)
  test_set_size = int(len(data) * test_ratio) #length of data into 0.2
  test_indices= shuffled[:test_set_size] #0 to test_set
  train_indices= shuffled[test_set_size:] #test_set to end
  return data.iloc[train_indices] , data.iloc[test_indices]

# %%
from sklearn.model_selection import train_test_split
train_set , test_set = train_test_split(df , test_size=0.2 , random_state=42)
print(f"Rows in train set : {len(train_set)}")
print(f"Rows in test set : {len(test_set)}")
# Out:
# Rows in train set : 120
# Rows in test set : 30

# %%
X = df[['PetalLengthCm','PetalWidthCm','SepalLengthCm','SepalWidthCm']].values
Y = df[['Species']].values

# %% [markdown]
# # **1) LOGISTIC REGRESSION**

# %%
model = LogisticRegression()
model.fit(X, Y)
# Out:
# LogisticRegression()

# %%
model.score(X,Y)
# Out:
# 0.9733333333333334

# %%
expected = Y
predicted = model.predict(X)
predicted
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
print(metrics.classification_report(expected, predicted))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        50
# Iris-versicolor       0.98      0.94      0.96        50
#  Iris-virginica       0.94      0.98      0.96        50
#
#        accuracy                           0.97       150
#       macro avg       0.97      0.97      0.97       150
#    weighted avg       0.97      0.97      0.97       150

# %%
print(metrics.classification_report(expected, predicted))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        50
# Iris-versicolor       0.98      0.94      0.96        50
#  Iris-virginica       0.94      0.98      0.96        50
#
#        accuracy                           0.97       150
#       macro avg       0.97      0.97      0.97       150
#    weighted avg       0.97      0.97      0.97       150

# %% [markdown]
# # **2) KNN MODEL**

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
k_range = list(range(48,65))
acc = []
for i in k_range:
  knn=KNeighborsClassifier(n_neighbors=i).fit(X_train,Y_train)
  Y_pred = knn.predict(X_test)
  acc.append(metrics.accuracy_score(Y_test,Y_pred))

# %%
acc
# Out:
# [0.8444444444444444,
#  0.8444444444444444,
#  0.8444444444444444,
#  0.8444444444444444,
#  0.8222222222222222,
#  0.8222222222222222,
#  0.8,
#  0.8,
#  0.8,
#  0.8222222222222222,
#  0.8,
#  0.8222222222222222,
#  0.8,
#  0.8222222222222222,
#  0.8,
#  0.7555555555555555,
#  0.7777777777777778]

# %% [markdown]
# # **3)DECISION TREE**

# %%
model_DTC = DecisionTreeClassifier()
model_DTC.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction = model_DTC.predict(X_train)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_train,prediction)*100)
for i in range(len(prediction)):
  print(X_train[i],prediction[i])
# Out:
# 100.0
# [4.9 1.8 6.1 3. ] Iris-virginica
# [1.5 0.1 4.9 3.1] Iris-setosa
# [5.5 1.8 6.4 3.1] Iris-virginica
# [5.4 2.3 6.2 3.4] Iris-virginica
# [1.5 0.4 5.7 4.4] Iris-setosa
# [4.7 1.4 7.  3.2] Iris-versicolor
# [1.5 0.3 5.1 3.8] Iris-setosa
# [1.5 0.2 5.  3.4] Iris-setosa
# [6.6 2.1 7.6 3. ] Iris-virginica
# [4.6 1.3 6.6 2.9] Iris-versicolor
# [1.5 0.2 5.3 3.7] Iris-setosa
# [6.3 1.8 7.3 2.9] Iris-virginica
# [4.8 1.8 5.9 3.2] Iris-versicolor
# [4.7 1.6 6.3 3.3] Iris-versicolor
# [1.4 0.2 5.  3.3] Iris-setosa
# [5.6 2.1 6.4 2.8] Iris-virginica
# [1.9 0.2 4.8 3.4] Iris-setosa
# [6.  2.5 6.3 3.3] Iris-virginica
# [1.5 0.2 4.6 3.1] Iris-setosa
# [5.1 1.5 6.3 2.8] Iris-virginica
# [1.5 0.1 4.9 3.1] Iris-setosa
# [5.6 1.4 6.1 2.6] Iris-virginica
# [1.4 0.2 5.2 3.4] Iris-setosa
# [5.9 2.1 7.1 3. ] Iris-virginica
# [4.  1.3 5.5 2.5] Iris-versicolor
# [4.  1.3 5.5 2.3] Iris-versicolor
# [4.1 1.  5.8 2.7] Iris-versicolor
# [3.9 1.4 5.2 2.7] Iris-versicolor
# ...
